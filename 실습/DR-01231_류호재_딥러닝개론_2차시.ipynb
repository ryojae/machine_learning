# %%
import numpy as np

X=np.arange(0,9,1.)
X

# %%
Y = np.reshape(X,(3,3))
Y

# %%
X.shape = (3,3)

# %%
a = np.arange(3)
a.astype(int) #int64

# %%
a.astype('int32')

# %%
a.astype('int64')

# %%
a.astype(float)#float64

# %%
a.astype('float32')

# %%
a.astype('float64')

# %%
a = np.array([1.2, -1.3, 2.2, 5.3, 3.7])
a

# %%
print(a[0])
print(a[0:3])
print(a[-1])
print(a[-2])
print(a[0:-1])

# %%
print(a)
idx = [0,3]
print(a[idx])

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[5,6]])
np.concatenate((a,b),axis=0)

# %%
np.concatenate((a,b.T),axis=1)

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
np.vstack((a,b))

# %%
np.hstack((a,b))

# %%
c = np.append(a,b)
c

# %%
a = np.array([1, 2, 3, 4])
b = np.array([4, 5, 6, 7])
a+b

# %%
a*b

# %%
a**b

# %%
a+2

# %%
10*np.sin(a)

# %%
a<3

# %%
a *= b
a

# %%
A = np.arange(9.).reshape(3,3)
x = np.array([1.,0,0])
y = x.reshape(1,3)
z = x.reshape(3,1)
print(A)
print(x)
print(y)
print(z)

# %%
A+1

# %%
A+x # expand with (3,3) x -> [[1,0,0].[1,0,0],[1,0,0]]

# %%
A+y # expand with (3,3) y -> [[1,0,0].[1,0,0],[1,0,0]]

# %%
A+z # expand with (3,3) z -> [[1,1,1].[0,0,0],[0,0,0]]

# %%
y+z # y -> [[1,0,0].[1,0,0],[1,0,0]]  z -> [[1,1,1].[0,0,0],[0,0,0]]

# %% [markdown]
# #pandas

# %%
import pandas as pd

# %%
# !cp /content/drive/MyDrive/두산_로보틱스_머신러닝/train.csv /content

# %%
df = pd.read_csv('/content/drive/MyDrive/두산_로보틱스_머신러닝/train.csv')
df

# %%
df.loc[0]

# %%
df.loc[[0]]

# %%
df.loc[1,'Name']

# %%
df.loc[8,'Name']

# %%
df.loc[8,'Fare']

# %%
df.loc[:,['Name','Fare']]

# %%
df.loc[:,'Name']

# %%
df.loc[:,:'Name']

# %%
df.loc[:,:'Age']

# %%
df.loc[:,'Survived':'Sex']

# %%
df.loc[:4,:'Name']

# %%
df.loc[:9,'Survived':'Age']

# %%
df.loc[10:19,'Survived':'Age']

# %%
condition = (df['Pclass']==3) & (df['Survived'] == 1)
df.loc[condition]

# %%
condition =(df['Survived'] == 1)
df.loc[condition]

# %%
df.iloc[0]

# %%
df.iloc[1,3]

# %%
df.iloc[:,3]

# %%
df.iloc[:,:3]

# %%
df.iloc[:3,:3]

# %%
df['Name']

# %%
df[['Pclass', 'Name']]

# %%
df['Survived'].mean()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1,50)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,200,100)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1,50)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1,'r-*',
          label=r'$sin(4 \pi x)$', lw = 1)
plt.plot(x,y2,'b--o',
         label=r'$ e^{-2x} sin(4\pi x) $', lw=1)
plt.title(r'$sin(4 \pi x)$ vs. $e^2{-2x} sin(4\pi x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.text(0.5,-1.0,r'This is sample')
plt.axis([0,1,-1.5,1.5])
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1,50)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.subplot(2,1,1)
plt.plot(x,y1,'r-*',lw=1)
plt.grid(True)
plt.ylabel(r'$sin(4 \pi x)$')
plt.axis([0,1,-1.5,1.5])

plt.subplot(2,1,2)
plt.plot(x,y2,'b--o',lw=1)
plt.grid(True)
plt.xlabel('x')
plt.ylabel(r'$ e^{-2x} sin(4\pi x)$')
plt.axis([0,1,-1.5,1.5])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax = fig.gca(projection = '3d')

theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)

r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

ax.plot(x, y, z, label='parametric curve')
ax.scatter(x,y,z)
ax.legend()

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import pi

a = np.arange(10,30,5)
b = np.arange(0,2,0.3)

print(a)
print(b)

c = np.linspace(0,2,15)
print(c)

x = np.linspace(0,2*pi,100)
f = np.sin(x)
print(f)

points = np.arange(-5,5,0.01)
xs,ys = np.meshgrid(points,points)

z = np.sqrt(xs**2+ys**2)

plt.imshow(z, cmap=plt.cm.gray)
plt.colorbar()
plt.title("Image")

# %% [markdown]
# #타이타닉 분석

# %%
import seaborn as sns
import pandas as pd
titanic = sns.load_dataset('titanic')
titanic

# %%
titanic.isnull().sum()

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].median())
titanic['embark_town'].value_counts()

# %%
titanic['embark_town'] = titanic['embark_town'].fillna('Southampton')
titanic['deck'].value_counts()

# %%
titanic['deck'] = titanic['deck'].fillna('C')
titanic['embarked'].value_counts()

# %%
titanic['embarked'] = titanic['embarked'].fillna('S')
titanic.isnull().sum()

# %%
titanic.info()

# %%
titanic.parch.value_counts()

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1,2,figsize=(10,5))
titanic['survived'][titanic['sex']=='male'].value_counts().plot.pie(explode=[0,0.1],
                                                                autopct='%1.1f%%',
                                                                ax=ax[0],
                                                                shadow=True)
titanic['survived'][titanic['sex']=='female'].value_counts().plot.pie(explode=[0,0.1],
                                                                autopct='%1.1f%%',
                                                                ax=ax[1],
                                                                shadow=True)
ax[0].set_title('Survived (Male)')
ax[1].set_title('Survived (Female)')
plt.show()

# %%
sns.countplot(x='pclass',hue='survived', data = titanic)
plt.title('Pclass vs Survived')
plt.show()

# %%
# titanic_numeric = titanic.select_dtypes(include=['float64', 'int64'])
titanic['sex'] = titanic['sex'].map({'male':0,'female':1})
titanic['who'] = titanic['who'].map({'man':1,'woman':0, 'child':-1})
titanic_corr = titanic.corr(method = 'pearson',numeric_only=True)
titanic_corr

# %% [markdown]
# #데이터 모델링

# %%
sns.pairplot(titanic, hue ='survived')
plt.show()

# %%
sns.catplot(x='pclass', y = 'survived', hue = 'sex',data = titanic, kind = 'point')
plt.show()

# %%
def category_age(x):
    if x<10:
        return 0
    elif x<20:
        return 1
    elif x<30:
        return 2
    elif x<40:
        return 3
    elif x<50:
        return 4
    elif x<60:
        return 5
    elif x<70:
        return 6
    else:
        return 7

titanic['age2'] = titanic['age'].apply(category_age)
titanic['sex'] = titanic['sex'].map({'male':0,'female':1})
titanic['family'] = titanic['sibsp'] + titanic['parch']+1
titanic.to_csv('titanic3.csv',index =False)
heatmap_data = titanic[['survived','sex','age2','family','pclass','fare']]
colormap = plt.cm.RdBu
sns.heatmap(heatmap_data.astype(float).corr(),linewidths=0.1,vmax=1.0,
            square=True,cmap=colormap,linecolor='white',annot=True,
            annot_kws={'size':10})
plt.show()

# %% [markdown]
# #원핫인코딩

# %%
import pandas as pd

# %%
# !git clone https://github.com/taehojo/data.git

# %%
df = pd.read_csv('./data/iris3.csv')
df.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

sns.pairplot(df, hue='species')
plt.show()

# %%
x = df.iloc[:,0:4]
y = df.iloc[:,4]
print(x[0:5])
print(y[0:5])
y

# %%
y =pd.get_dummies(y)
print(y)
df = pd.concat([df, y], axis=1)

# 원본 열을 제거하고 싶다면
df.drop(['species'], axis=1, inplace=True)

# %%
df

# %%
model = Sequential()
model.add(Dense(12, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x, y, epochs=50, batch_size=5)

# %%
history

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./data/pima-indians-diabetes3.csv')
df.head(10)

# %%
df.isnull().sum()

# %%
df.describe()
